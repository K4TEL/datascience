# %%
import pandas as pd
import numpy as np

# %%
# connecting to gdrive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
gdrive_path = f"/content/gdrive/MyDrive/ds/"
# Out:
# Mounted at /content/gdrive

# %%
# reading dataset to pandas dataframe
data = pd.read_csv("/content/gdrive/MyDrive/ds/IBM.csv")
# show first 20 rows
data.head(20)
# Out:
#     Age Attrition              Department  DistanceFromHome  Education  \
# 0    41       Yes                   Sales                 1          2
# 1    49        No  Research & Development                 8          1
# 2    37       Yes  Research & Development                 2          2
# 3    33        No  Research & Development                 3          4
# 4    27        No  Research & Development                 2          1
# 5    32        No  Research & Development                 2          2
# 6    59        No  Research & Development                 3          3
# 7    30        No  Research & Development                24          1
# 8    38        No  Research & Development                23          3
# 9    36        No  Research & Development                27          3
# 10   35        No  Research & Development                16          3
# 11   29        No  Research & Development                15          2
# ...

# %%
# show dataframe column EducationField
data.EducationField
# Out:
# 0       Life Sciences
# 1       Life Sciences
# 2               Other
# 3       Life Sciences
# 4             Medical
#             ...
# 1465          Medical
# 1466          Medical
# 1467    Life Sciences
# 1468          Medical
# 1469          Medical
# Name: EducationField, Length: 1470, dtype: object

# %%
# show dataframe column Department
data["Department"]
# Out:
# 0                        Sales
# 1       Research & Development
# 2       Research & Development
# 3       Research & Development
# 4       Research & Development
#                  ...
# 1465    Research & Development
# 1466    Research & Development
# 1467    Research & Development
# 1468                     Sales
# 1469    Research & Development
# Name: Department, Length: 1470, dtype: object

# %%
# show cell content at 43rd row of the column Age
data["Age"][42]
# Out:
# 26

# %%
# show first row of the dataframe
data.iloc[0]
# Out:
# Age                                   41
# Attrition                            Yes
# Department                         Sales
# DistanceFromHome                       1
# Education                              2
# EducationField             Life Sciences
# EnvironmentSatisfaction                2
# JobSatisfaction                        4
# MaritalStatus                     Single
# MonthlyIncome                       5993
# NumCompaniesWorked                     8
# WorkLifeBalance                        1
# YearsAtCompany                         6
# Name: 0, dtype: object

# %%
# show all rows for 6th column
data.iloc[:, 5]
# Out:
# 0       Life Sciences
# 1       Life Sciences
# 2               Other
# 3       Life Sciences
# 4             Medical
#             ...
# 1465          Medical
# 1466          Medical
# 1467    Life Sciences
# 1468          Medical
# 1469          Medical
# Name: EducationField, Length: 1470, dtype: object

# %%
# show rows from 42nd to 420th of the 3rd column
data.iloc[42:420, 2]
# Out:
# 42     Research & Development
# 43                      Sales
# 44     Research & Development
# 45     Research & Development
# 46                      Sales
#                 ...
# 415                     Sales
# 416    Research & Development
# 417                     Sales
# 418    Research & Development
# 419    Research & Development
# Name: Department, Length: 378, dtype: object

# %%
# show rows from 42nd to 420th with a step 3 for the 9th column
data.iloc[42:420:3, 8]
# Out:
# 42      Single
# 45     Married
# 48      Single
# 51      Single
# 54     Married
#         ...
# 405    Married
# 408    Married
# 411    Married
# 414     Single
# 417    Married
# Name: MaritalStatus, Length: 126, dtype: object

# %%
# show first 3 rows of the dataframe
data.iloc[:3]
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
# 2   37       Yes  Research & Development                 2          2
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
# 2          Other                        4                3        Single
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# 0           5993                   8                1               6
# 1           5130                   1                3              10
# 2           2090                   6                3               0

# %%
# show last 5 rows of the dataframe
data.iloc[-5:]
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 1465        Medical                        3                4       Married
# 1466        Medical                        4                1       Married
# 1467  Life Sciences                        2                2       Married
# 1468        Medical                        4                2       Married
# 1469        Medical                        2                3       Married
#
# ...

# %%
# show cell content at 7th row of the column YearsAtCompany
data.loc[7, "YearsAtCompany"]
# Out:
# 1

# %%
# show all rows of the columns MonthlyIncome, Department, and EducationField
data.loc[:, ["MonthlyIncome", "Department", "EducationField"]]
# Out:
#       MonthlyIncome              Department EducationField
# 0              5993                   Sales  Life Sciences
# 1              5130  Research & Development  Life Sciences
# 2              2090  Research & Development          Other
# 3              2909  Research & Development  Life Sciences
# 4              3468  Research & Development        Medical
# ...             ...                     ...            ...
# 1465           2571  Research & Development        Medical
# 1466           9991  Research & Development        Medical
# 1467           6142  Research & Development  Life Sciences
# 1468           5390                   Sales        Medical
# 1469           4404  Research & Development        Medical
#
# [1470 rows x 3 columns]

# %%
# show first 11 rows of the columns MonthlyIncome, Department, and EducationField
data.loc[:10, ["MonthlyIncome", "Department", "EducationField"]]
# Out:
#     MonthlyIncome              Department EducationField
# 0            5993                   Sales  Life Sciences
# 1            5130  Research & Development  Life Sciences
# 2            2090  Research & Development          Other
# 3            2909  Research & Development  Life Sciences
# 4            3468  Research & Development        Medical
# 5            3068  Research & Development  Life Sciences
# 6            2670  Research & Development        Medical
# 7            2693  Research & Development  Life Sciences
# 8            9526  Research & Development  Life Sciences
# 9            5237  Research & Development        Medical
# 10           2426  Research & Development        Medical

# %%
# show rows from 420th to 777th with a step 6 for the columns 
# MonthlyIncome, Department, and EducationField
data.loc[420:777:6, ["MonthlyIncome", "Department", "EducationField"]]
# Out:
#      MonthlyIncome              Department    EducationField
# 420          11935  Research & Development           Medical
# 426           2564  Research & Development           Medical
# 432           2768  Research & Development     Life Sciences
# 438           7632  Research & Development     Life Sciences
# 444           4051                   Sales         Marketing
# 450           6582                   Sales     Life Sciences
# 456          11557                   Sales     Life Sciences
# 462           5337                   Sales     Life Sciences
# 468           5577  Research & Development  Technical Degree
# 474           2725  Research & Development           Medical
# 480           2033                   Sales     Life Sciences
# 486           9602                   Sales         Marketing
# 492          15402  Research & Development     Life Sciences
# 498           2773  Research & Development           Medical
# ...

# %%
# set column Age as dataframe index
data.set_index("Age")
# Out:
#     Attrition              Department  DistanceFromHome  Education  \
# Age
# 41        Yes                   Sales                 1          2
# 49         No  Research & Development                 8          1
# 37        Yes  Research & Development                 2          2
# 33         No  Research & Development                 3          4
# 27         No  Research & Development                 2          1
# ..        ...                     ...               ...        ...
# 36         No  Research & Development                23          2
# 39         No  Research & Development                 6          1
# 27         No  Research & Development                 4          3
# 49         No                   Sales                 2          3
# 34         No  Research & Development                 8          3
#
#     EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# Age
# ...

# %%
# get mean of the column MonthlyIncome
mi_mean = data.MonthlyIncome.mean()
print("Mean monthly income =", mi_mean)
# show dataframe rows which have greater than mean MonthlyIncome
data.loc[data.MonthlyIncome > mi_mean]
# Out:
# Mean monthly income = 6502.931292517007
#       Age Attrition              Department  DistanceFromHome  Education  \
# 8      38        No  Research & Development                23          3
# 15     29        No  Research & Development                21          4
# 18     53        No                   Sales                 2          4
# 22     34        No  Research & Development                 7          4
# 25     53        No  Research & Development                 5          3
# ...   ...       ...                     ...               ...        ...
# 1453   36        No                   Sales                11          4
# 1461   50       Yes                   Sales                28          3
# 1462   39        No                   Sales                24          1
# 1463   31        No  Research & Development                 5          3
# 1466   39        No  Research & Development                 6          1
#
# ...

# %%
# show dataframe rows which have greater than mean MonthlyIncome AND 
# MaritalStatus equl to Single
data.loc[(data.MonthlyIncome > mi_mean) & (data.MaritalStatus == "Single")]
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 8      38        No  Research & Development                23          3
# 22     34        No  Research & Development                 7          4
# 29     46        No                   Sales                 2          4
# 43     27        No                   Sales                 8          3
# 55     33        No  Research & Development                 1          2
# ...   ...       ...                     ...               ...        ...
# 1403   39        No                   Sales                15          4
# 1414   47        No  Research & Development                25          3
# 1437   39        No  Research & Development                 9          3
# 1450   35        No         Human Resources                26          4
# 1463   31        No  Research & Development                 5          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
# show dataframe rows of the Research & Development Department OR
# Married MaritalStatus
data.loc[(data.Department == "Research & Development") | (data.MaritalStatus == "Married")]
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 1      49        No  Research & Development                 8          1
# 2      37       Yes  Research & Development                 2          2
# 3      33        No  Research & Development                 3          4
# 4      27        No  Research & Development                 2          1
# 5      32        No  Research & Development                 2          2
# ...   ...       ...                     ...               ...        ...
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
# show datafarme rows where EducationField is in a list of values ["Life Sciences", "Medical"]
data.loc[data.EducationField.isin(["Life Sciences", "Medical"])]
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 0      41       Yes                   Sales                 1          2
# 1      49        No  Research & Development                 8          1
# 3      33        No  Research & Development                 3          4
# 4      27        No  Research & Development                 2          1
# 5      32        No  Research & Development                 2          2
# ...   ...       ...                     ...               ...        ...
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
# show dataframe rows in a range of 4-5 for the column JobSatisfaction
data.loc[data.JobSatisfaction.isin([5, 4])]
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 0      41       Yes                   Sales                 1          2
# 5      32        No  Research & Development                 2          2
# 13     34        No  Research & Development                19          2
# 17     22        No  Research & Development                16          2
# 18     53        No                   Sales                 2          4
# ...   ...       ...                     ...               ...        ...
# 1451   38        No                   Sales                10          2
# 1453   36        No                   Sales                11          4
# 1458   35        No  Research & Development                 1          4
# 1462   39        No                   Sales                24          1
# 1465   36        No  Research & Development                23          2
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...

# %%
# show dataframe rows where Age column is not filled
data.loc[data.Age.isnull()] # note: all data is non null
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, Department, DistanceFromHome, Education, EducationField, EnvironmentSatisfaction, JobSatisfaction, MaritalStatus, MonthlyIncome, NumCompaniesWorked, WorkLifeBalance, YearsAtCompany]
# Index: []

# %%
# set new column with a value "data" in all rows
data["Column"] = "data"
data.Column
# Out:
# 0       data
# 1       data
# 2       data
# 3       data
# 4       data
#         ...
# 1465    data
# 1466    data
# 1467    data
# 1468    data
# 1469    data
# Name: Column, Length: 1470, dtype: object

# %%
# set new column with values ranging from 0 up to rows number in a reversed order
data['my_index'] = range(len(data), 0, -1)
data['my_index']
# Out:
# 0       1470
# 1       1469
# 2       1468
# 3       1467
# 4       1466
#         ...
# 1465       5
# 1466       4
# 1467       3
# 1468       2
# 1469       1
# Name: my_index, Length: 1470, dtype: int64

# %%
# demonstration of the new columns next to the old ones
data
# Out:
#       Age Attrition              Department  DistanceFromHome  Education  \
# 0      41       Yes                   Sales                 1          2
# 1      49        No  Research & Development                 8          1
# 2      37       Yes  Research & Development                 2          2
# 3      33        No  Research & Development                 3          4
# 4      27        No  Research & Development                 2          1
# ...   ...       ...                     ...               ...        ...
# 1465   36        No  Research & Development                23          2
# 1466   39        No  Research & Development                 6          1
# 1467   27        No  Research & Development                 4          3
# 1468   49        No                   Sales                 2          3
# 1469   34        No  Research & Development                 8          3
#
#      EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# ...
